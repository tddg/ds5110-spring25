# %%
import dask
from dask.distributed import Client
import dask.array as da

# %%
client = Client('172.31.81.147:8786')
client = client.restart()
print(client)
# Out:
# <Client: 'tcp://172.31.81.147:8786' processes=0 threads=0, memory=0 B>

# %%
x = da.random.normal(size=1_000_000, chunks=100_000)  # 1 million items with a chunk size of 100k (10 chunks)

# %%
data = x.compute()

# %%
dask.visualize(x)

# %%
x = da.random.normal(size=1_000_000, chunks=10_000)  # 1 million items with a chunk size of 10k (100 chunks)

# %%
dask.visualize(x)

# %%
x = da.ones((15,15), chunks=(5,5))

y = x + x.T

y.visualize()

# %%
y
# Out:
# dask.array<add, shape=(15, 15), dtype=float64, chunksize=(5, 5), chunktype=numpy.ndarray>

# %%
y.dask
# Out:
# HighLevelGraph with 3 layers.
# ...
#  0. ones_like-d6ea2907cb1ce15d1ee8e0ee86c69e1d
#  1. transpose-fb85609b2c1bab7054e50ac79f194a59
#  2. add-d52096265fb912ce91cfa77d87a9d292
